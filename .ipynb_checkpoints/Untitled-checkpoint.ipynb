# %%
import pandas as pd
from flask import Flask,jsonify
app = Flask(__name__)
import PyPDF2
import re
import string
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import matplotlib.pyplot as plt
import pickle
# creating a pdf file object

  
# creating a pdf reader object
#pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
from dotenv import load_dotenv
load_dotenv()

import cloudinary
import cloudinary.uploader
import cloudinary.api

# %%
import json

# %%
config = cloudinary.config(cloud_name="ayeshank",api_key="674815643198743",api_secret="EQQOHrESgYyMV57FioSs48O2j3k")

# Log the configuration
# ==============================
print("****1. Set up and configure the SDK:****\nCredentials: ", config.cloud_name, config.api_key, "\n")
# Out:
# ****1. Set up and configure the SDK:****
# Credentials:  ayeshank 674815643198743

# %%
import cloudinary.api
var = cloudinary.api.resource("hmwbckieimbjzs9lwdkh")
data=var['info']['ocr']['adv_ocr']['data']
box=data[0]['fullTextAnnotation']['text']
print(box)
print(type(box))
# Out:
# LACE
# TURE
# CE
# PLACE
# PICTURE LACE
# PICTURE
# HERE
# MUFREAH
# AQEEL
# UNDERGRADUATE-BSCS
# ABOUT ME
# A goal oriented person who love exploring
# and testing new aspects in life. Thriving and
# living upon the principle of hard work and
# smartwork.
# CONTACT ME
# North Nazimabad, block 'H', Karachi.
# Postal code: 74700
# +92 321 2061386
# +92 321 8999295
# mufreahaqeel@gmail.com
# MY SKILLS
# Ms Word
# C#
# python
# SQL
# HTML/CSS
# Problem Solving
# INTERESTS
# Football / Cricket
# Badminton / Games
# EDUCATION
# Bachelors in
# Computer Science
# 2019-2023(expected)
# University: PAF-KIET
# Intermediate:
# 2016-2018
# College: Govt. Degree Girls College (Shaikh Zaid Center)
# Matriculation:
# 2015-2017/18
# School: The Vision School
# Projects:
# Hospital Management:
# C#. OOP concepts
# One on One Communicating Software
# Five features, networking procols.
# School Website
# Front-End Developing, HTML/CSS
# <class 'str'>

# %%
to_text = box
count = 0

if box is not None:
    
    #pdfReader = PyPDF2.PdfFileReader(box)
    #num_pages = pdfReader.numPages
        # Extract text from every page on the file
    #while count < num_pages:
        #pageObj = pdfReader.getPage(count)
        #count +=1
        #to_text += pageObj.extractText()
            #st.write(to_text)
    to_text = to_text.lower()
            # Remove numbers
    to_text = re.sub(r'\d+','',to_text)
            # Remove punctuation
    to_text = to_text.translate(str.maketrans('','',string.punctuation))
    print(to_text)
# Out:
# lace
# ture
# ce
# place
# picture lace
# picture
# here
# mufreah
# aqeel
# undergraduatebscs
# about me
# a goal oriented person who love exploring
# and testing new aspects in life thriving and
# living upon the principle of hard work and
# smartwork
# contact me
# north nazimabad block h karachi
# postal code
#
#
# mufreahaqeelgmailcom
# my skills
# ms word
# c
# python
# sql
# htmlcss
# problem solving
# interests
# football  cricket
# badminton  games
# education
# bachelors in
# computer science
# expected
# university pafkiet
# intermediate
#
# college govt degree girls college shaikh zaid center
# matriculation
#
# school the vision school
# projects
# hospital management
# c oop concepts
# one on one communicating software
# five features networking procols
# school website
# frontend developing htmlcss

# %%
transformer = TfidfTransformer()
loaded_vec = CountVectorizer(decode_error="replace",vocabulary=pickle.load(open("svm-model.pkl", "rb")))
        #tfidf = transformer.fit_transform(loaded_vec.fit_transform(requiredText))
test_feature = loaded_vec.transform([to_text])
model = pickle.load(open("mnb_model.pkl","rb"))
prediction = model.predict(test_feature)
if prediction == 0:
    print("YOUR CV MATCHES APPLICATION CONSULTANT")
elif prediction ==1:
    print("YOUR CV MATCHES DATA ANALYST")
elif prediction ==2:
    print("YOUR CV MATCHES JAVA DEVELOPER")
elif prediction ==3:
    print("YOUR CV MATCHES PROJECT MANAGER")
else:
    print("Sorry,Your CV didnot match any of the available job openings")
# Out:
#   File "<ipython-input-19-564ec8f40713>", line 2
#     loaded_vec = CountVectorizer(decode_error="replace",vocabulary=pickle.load(open("svm-model.pkl", "rb")))
#     ^
# IndentationError: unexpected indent

# %%
import urllib.request

get_url= urllib.request.urlopen('https://res.cloudinary.com/ayeshank/image/upload/v1659975532/CandidateResumes/undefinedSalar%20Khan.pdf')

print("Response Status: "+ str(get_url.getcode()))

print(get_url.read())
x = requests.post(get_url)
    #print the response text (the content of the requested file):
print(x.text)
# Out:
# Response Status: 200
# b'%PDF-1.5\r\n%\xb5\xb5\xb5\xb5\r\n1 0 obj\r\n<</Type/Catalog/Pages 2 0 R/Lang(en-US) /StructTreeRoot 66 0 R/MarkInfo<</Marked true>>>>\r\nendobj\r\n2 0 obj\r\n<</Type/Pages/Count 1/Kids[ 3 0 R] >>\r\nendobj\r\n3 0 obj\r\n<</Type/Page/Parent 2 0 R/Resources<</Font<</F1 5 0 R/F2 11 0 R/F3 17 0 R/F4 25 0 R>>/XObject<</Image8 8 0 R/Image9 9 0 R/Image13 13 0 R/Image15 15 0 R/Image19 19 0 R/Image21 21 0 R/Image23 23 0 R/Image30 30 0 R/Image32 32 0 R/Image34 34 0 R/Image36 36 0 R/Image38 38 0 R/Image40 40 0 R/Image42 42 0 R/Image44 44 0 R/Image46 46 0 R/Image48 48 0 R/Image50 50 0 R/Image52 52 0 R/Image54 54 0 R/Image56 56 0 R/Image58 58 0 R/Image61 61 0 R/Image63 63 0 R>>/Pattern<</P7 7 0 R>>/ProcSet[/PDF/Text/ImageB/ImageC/ImageI] >>/MediaBox[ 0 0 595.44 841.68] /Contents 4 0 R/Group<</Type/Group/S/Transparency/CS/DeviceRGB>>/Tabs/S/StructParents 0>>\r\nendobj\r\n4 0 obj\r\n<</Filter/FlateDecode/Length 4157>>\r\nstream\r\nx\x9c\xad\x1cks\xd56\xf6;3\xfc\x07\xcd\xf4\x8b\xdd6\x8e\xf5\x96\x99Ng!$\xc0\x96\x00\x85t;\xbbt?\xa4\x97K\xc86\xb9I\x93\x00\xdb\xfd\xf5{\xce\x91\xec+\xd9\xd6\xbd\xf6\x85\xe9\xd4\xbdV\xa4\xf3\xd2yK.\xdb\x7f\xc5~\xf8a\xff\xf8\xe0\xd9cV\xff\xf8#{\xf4\xf8\x80=:\xb9\x7fo\xff\x883.\xd8\xc9\xfb\xfb\xf78\xab\xe1\x1f\xce\x84\xab\xa4`\xae\x16\x95R\xec\xe4\xf2\xfe\xbd\x9a\x9d\xe1\xe3\xc9\xfd{o\x0bV\xfe\x9b\x9d\xfc\xfd\xfe\xbdCX\xcb\x0e\x8f\x0f\x18\x8b\x00\xf3\x00\xb8\xae\x84X?\x14\xbb\xa1\xf5{\xdcVJ0!m\xe5\x1cs\xba\xa98\xbbY\xde\xbf\xf7\xfe\xdb\x11P"\x80\xe2\x88\x9b\xf3\xa62\x92ic*\xde0^WV\x03d\x9d_-\xdb\xd5VV\x1c\x16rS\x99\x86\x01+\xd6\xb6/\x17\xfeE:\xe4\x12^\xda\xa9\x83\x81n\xfa\x07\\\x81\xa852\xa2\x10\x1c\xb7\x82\x08\xf3\x03\x17\xeb\x01\xe0\xb1\xc5A+\xfa\xef\xdd\x82\x0f\x19\x0eT\xcb\x81#\x80\xd2Y\xdc\x14@i,0\x1e^/\xc2\xab\xaa\x9b\xaa\xb6\x84\xdfO\x1f\x0c\xac\x17\x00B\xe3*\xe1a8\x02\x89s\xb8l\x07.\xba\x01U\xbb\x16\x0b\xad\xe8\xbf\xaf\x17\xe4\xb8\xd0\xd1>H\xc7\x04\xa8\x96G\t\xa2\x0f/~\x1f\x84\xae\x03\xe8v\xea`\xa0\x9b\xee\xf7A\xc3H\x13d\x82Rw\xae\x1d\xb8X\x0f\xa8\xa6C\x81\x0bz\xaf\xdd\xf4\x1c\xf9&%\x9f\x03\xffN\x06\xf2\xc3\x8b\'\x9fKPG\x17Q;\x1c\xe8\xa6\xb7\xe4s\xd8#\x98\xb2&?\x0c\xac\xc9G \xb5\xeb\xe8\xed\xbfv\xd3s\xe4\xdb@\xfe\x9f`\xe6\xafN\xef\xee\x967+\xb6\xb8\x85\x19\x96\xdd.V\x00\x86\x0c\xc9\n\xd0M\xa2#\xbckxW\xac\xd1Um,\xb3\x8eW\x8d\x04\x17\x81\xaf\xed\xdb\x02H\xd4\xf1\x00\xb7\r2\x19\x96\xb6o\x1e0N\xf6\x03\xa6\x01\xe5\x17,,5 \x18\xd5A\x0eo09 \x0e\x03\x9e\xa6\xb02!x\xd11\xfe\xf3\x08\xefn\xcd;7\xa2\x92\x86\x9c\x1b`n\x04S\x12\xd7k\xd7\xa08\x17\xc0\xf8\xfe\xb3\xcb\xd3\xb3e\xc3\x1e_\xb11X\xcd\x1aV\xb24\x00\xf6@\xd1\x17\xfd\xfa-\x03\xb1z\xb7*\x98\x14U\xad\x12\xcf\xaaee\x9dbF\x88J{\xd7\xea\xdd\x9bw\xad\xc7\xbf\x1c\xbd>|X\xca\xe2i\xe4c\x81\x9e\x1d\xd0\x9a\x14/\xe8\x0b\x0e\xe9F\xa1\xc6\xf4\xf1>,y]\xfc|x\x08\x98\x9f\x7f\x01f\x8c#U-R\xcc\xa8\xc9V\xc6\x98)\x98\xa4qdL\xe6\xbc\x8e6\x10\x00\x03\x11\x08Q\xc8J\x0b\x06\xee\x07\x9eZ\x93\xfd\xae7\x10\\Vf\x079_C[/\x06\x0f\x1c@\x03X5"\xca&\x95\xa2\xa9$,\xd1VU\xc2\x0e\xa4\xf8K\xa9\x8a\x17\x8fK[\x1c\x96{\xaex]\xea\xe2\xc9kx{X\xee\xa9\xe21\xfc\r\xffN/\'\xf88\x1c\x08zg\xb28x5crd\xed}EDZl@\xf4\xa8\xdc3\xc5\x1b`\xfb\xe0\xcdWD\x89\xceS\xe6Pn\xd5!\xb1\xdb\xaeW\x8dI\xa9\x10\n\xe3\x86F\xedo\xe6S!gS\xd1G\xac(v\xcc\xb1\x1e\xb5\xc6\t\xa6\x0b\xb6O\x00u\x05\xde\xc7\xd5\xe8\x96\xb4\xa8{\xc6\xa3\xb3\xc6\xa3#`\xf1b\x0f\xd9C\xed\x8b\x11\x1c\xbb\xea\xbb\xbf\x06b\x05\x1a\x10p\xa5\x87r|\xf8\xe8\xe5/\'\x0c\xac\xe4\x18\x94hh\x1f\x131\xaf\x95\xd5\x02\xb2\x18\xd7T\xd1\x998r@\xfe\xea\x03\x87A\xecJU\xd6\xc0\x93\x82Q$\xbal\xe4\xe06I\xb5\x81\xf0AH\xd0\xe4TT\x03!A\x8f\xb8f0*V\x9a\xe2\xac\xdc\xd3\xc5U\xc9yqz\x81\xfe\x05\xc7\xae\xca=Y\xdc\x94B\x14\xe78m\x191\x16K\xa2\x81\xa0\x99bx[\xac@\xc4w \xea%\xfc\xf7\x1d\x83\xc75\xc2\xc7\xb7\x1b\xf0Y\xb7\x00Y\xd0\x1cD\xf3\x19\xd1|@\xa7E\x08Y)xq\x81\x08\xe9\xf5\xd32L\xc3\xff\xfe\x17\x16\x13\xa4\x8b\xd2\xb5\xe4YO\x1dB#&X\x86Lp.\xa8\x1c\xca\x82\x89\xf0@\xe6\xe9\n\x88\xb3\x1d\xa5\xb7w\xf0\xe8C\xf3/\xf8\xe7\xcf\x19\xc8\xbc\xd6\x95\x11)\xe4\x1c\x15\xbc\xb6\x15w=*n\x81\'K(\x16An\xb7\xb9\xe ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fcfa91ce3ae2> in <module>
#       6
#       7 print(get_url.read())
# ----> 8 x = requests.post(get_url)
#       9     #print the response text (the content of the requested file):
#      10 print(x.text)
#
# NameError: name 'requests' is not defined

# %%
from urllib.request import Request, urlopen

req = Request('http://www.cmegroup.com/trading/products/#sortField=oi&sortAsc=false&venues=3&page=1&cleared=1&group=1', headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()

# %%
import urllib.request

link="https://drive.google.com/file/d/1VNnWX1C6rxcdreYJ1C6nslc8tko11BYv/view"
#link = "https://res.cloudinary.com/ayeshank/image/upload/v1659975532/CandidateResumes/undefinedSalar%20Khan.pdf"
#link = "https://pypi.org/project/requests/"
f = urllib.request.urlopen(link)
#myfile = f.read().decode(errors='replace')
myfile = f.read()

#print(myfile)
print (myfile.decode('latin1', 'strict'))

# %%
@app.route('/')
def index():
    return "new app"

# %%
to_text = ""
count = 0
Resume = open('Tooba.pdf', 'rb') 
if Resume is not None:
    pdfReader = PyPDF2.PdfFileReader(Resume)
    num_pages = pdfReader.numPages
    # Extract text from every page on the file
    while count < num_pages:
        pageObj = pdfReader.getPage(count)
        count +=1
        to_text += pageObj.extractText()
        #st.write(to_text)
        to_text = to_text.lower()
        # Remove numbers
        to_text = re.sub(r'\d+','',to_text)
        # Remove punctuation
        to_text = to_text.translate(str.maketrans('','',string.punctuation))
        #st.write(to_text)
else:
    single_review = st.sidebar.text_input('Enter single review below:')
     #st.write(to_text)
    to_text = single_review.lower()
    # Remove numbers
    to_text = re.sub(r'\d+','',to_text)
    # Remove punctuation
    to_text = to_text.translate(str.maketrans('','',string.punctuation))
    #st.write(to_text)
text=pd.DataFrame([to_text])

# %%
transformer = TfidfTransformer()
loaded_vec = CountVectorizer(decode_error="replace",vocabulary=pickle.load(open("svm-model.pkl", "rb")))
    #tfidf = transformer.fit_transform(loaded_vec.fit_transform(requiredText))
test_feature = loaded_vec.transform([to_text])



model = pickle.load(open("mnb_model.pkl","rb"))
prediction = model.predict(test_feature)

# %%
if prediction == 0:
    print("YOUR CV MATCHES APPLICATION CONSULTANT")
elif prediction ==1:
    print("YOUR CV MATCHES DATA ANALYST")
elif prediction ==2:
    print("YOUR CV MATCHES JAVA DEVELOPER")
elif prediction ==3:
    print("YOUR CV MATCHES PROJECT MANAGER")
else:
    print("Sorry,Your CV didnot match any of the available job openings")
# Out:
# YOUR CV MATCHES DATA ANALYST

# %%
terms = {     
         'ApplicationConsultant':['leadership','collaboration','ATM','conflict resolution','Digital Channels',
                                       'integration protocols','ATM/CCDM Controller','analytical','verbal',
                                       'ISO 8583 messages','IBFT','UBPS','Inter Bank Fund Transfers','Banking',
                                       'Utility Bill Payment Services ','banking','finance','7','7 years experience'
                                       'patient','reporting system','stake holder','Payments','client','satisfaction',
                                       'implementation','delivery','administration','agile','budget','cost','direction','feasibility analysis',                             'finance','kanban','leader','leadership','management','milestones','planning',
                              'pmi','pmp','problem','project','risk','schedule','scrum','stakeholders','operations','custom support','hardware','problem solving','database architecture',
       'programming skills','VMWare','Virtual Box','networking','Information System','Computer Engineering','TCP/IP','Customer Care Service','decision making',
       'cloud','solutions','designing','upgrading system','reporting system','associate application consultant'],
         
        
        'JAVADeveloper':['2 years experience ','JAVA','developer','development','rest','soap','api','REST','SOAP','API','Web Services','database structures',
                      'statistical analysis','analytical mindset','problem solving skills','api','application programming interface',
                      'verbal communication','excellent written skills','Java Programming Language','Ability to work','Software Engineeing','Computer Science','Masters in CS','fast pace environment','Bachelors','programming','coding','HTML','object oriented programming','OOP','java','java developer'],
    
        'DataAnalyst': [ 'model managment','database management','python','R','Data Science','Machine Learning','pandas','statistical analysis','analytical mindset','problem solving skills','Tableau','Hadoop',
                      'verbal communication','excellent written skills','SQL',' Programming Language','Ability to work','Software Engineeing','Computer Science','Masters in CS','fast pace environment','Bachelors','programming','coding','HTML','object oriented programming','OOP','java','python developer','python','streamlit']
    ,
    'ProjectManager':['Team Lead','Team Work','Milestone','Communication','Risk Management','MS office','Agile','3 years of experience',
                     'SAP Training ','PMP Certification','MS Excel','Bachelors','MS Word','verbal skills','time management',
                      'resource planning','Sprint','Project','Issues','Masters'
                     
                     ]}

# %%
developer = 0
consultant = 0
analyst = 0
manager = 0
# Create an empty list where the scores will be stored
scores = []

# Obtain the scores for each area
for area in terms.keys():
    if area == 'ApplicationConsultant':
        for word in terms[area]:
            if word in to_text:
                consultant+=1
        scores.append(consultant)
    elif area == 'JAVADeveloper':
        for word in terms[area]:
            if word in to_text:
                developer+=1
        scores.append(developer)

    elif area == 'DataAnalyst':
        for word in terms[area]:
            if word in to_text:
                analyst+=1
        scores.append(analyst)
     
      
    elif area =='ProjectManager':
        for word in terms[area]:
            if word in to_text:
                manager +=1
        scores.append(manager)
    else:
        scores = 0
summary = pd.DataFrame(scores,index=terms.keys(),columns=['score']).sort_values(by='score',ascending=False)

# %%
summary
# Out:
#                        score
# ApplicationConsultant      6
# JAVADeveloper              4
# DataAnalyst                3
# ProjectManager             0

# %%
app.add_url_rule('/',
                 view_func=main.as_view('main'),
                 methods = ['GET'])

app.add_url_rule('/terms',
                 view_func=main.as_view('page'),
                 methods = ['GET'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-aa5e36e2decd> in <module>
#       1 app.add_url_rule('/',
# ----> 2                  view_func=main.as_view('main'),
#       3                  methods = ['GET'])
#       4
#       5 app.add_url_rule('/terms',
#
# NameError: name 'main' is not defined

# %%
@app.route("/terms",methods=['GET'])
def get():
        return jsonify({'Summary':summary})
        
if __name__=="__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# UserWarning: To exit: use 'exit', 'quit', or Ctrl-D. [interactiveshell.py:3426]
